# %% [markdown]
# ## How can we represent dataframes as python objects?

# %%
people = {
    "first": ['Jack', 'James', 'Liam'],
    "last": ['Simons', 'Kabby', 'Payne'],
    "email":['jsim@demo.com', 'jkab@demo.com', 'lpayne@demo.com']
}

people["first"]
# Out:
# ['Jack', 'James', 'Liam']

# %%
# creating a dataframe from the above object

# %%
import pandas as pd
# creating a dataframe from the dict
df = pd.DataFrame(people)
df
# Out:
#    first    last            email
# 0   Jack  Simons    jsim@demo.com
# 1  James   Kabby    jkab@demo.com
# 2   Liam   Payne  lpayne@demo.com

# %%
# accessing data of the dataframe
df['email']
# ^ returns a series
# Alternative:
df.email
# Out:
# 0      jsim@demo.com
# 1      jkab@demo.com
# 2    lpayne@demo.com
# Name: email, dtype: object

# %%
type(df['email'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Dataframes - rows and columns
# # Series - rows of a single column

# %%
# accessing multiple col.s at once
df[['last', 'email']]
# ^ the return is not a series but another filtered dataframe
# ! Whenever we add a dataframe and assign that into some var, that df object
# would have col names as attrs and we can access a series bu using the name after a dot
# ! Also, the item naming is case sensitive
# Out:
#      last            email
# 0  Simons    jsim@demo.com
# 1   Kabby    jkab@demo.com
# 2   Payne  lpayne@demo.com

# %%
df.columns
# ^ grabbing col.s
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %% [markdown]
# # iloc()

# %%
# getting rows
df.iloc[0] 

# gettin multiple rows
df.iloc[[0, 1], 0] # <- allowing to get col.s as well
# enables us to access rows by an int location
# whenever we are using slicing, the right one is exclusive
# Out:
# 0     Jack
# 1    James
# Name: first, dtype: object

# %% [markdown]
# # We could also use a slicing with a dframe but that's not clear. So, just use iloc()

# %%
df.iloc[0:2, :]
# Out:
#    first    last          email
# 0   Jack  Simons  jsim@demo.com
# 1  James   Kabby  jkab@demo.com

# %% [markdown]
# # loc()

# %%
df.loc[0]
# ^ searching by the label
# since the 0 was passed, we have gotten the 1st row 

# getting multiple rows
df.loc[[0, 1], ['email', 'last']] 
# we pass the list of labels to get multiple col.s as well 
# ^ the list is also possible with the "iloc()"
# the order can be changed
# Out:
#            email    last
# 0  jsim@demo.com  Simons
# 1  jkab@demo.com   Kabby

# %% [markdown]
# ## !!! We can use a list slicing with loc() and the last value for that would be inclusive
#
# ## Also, we don't use []s around them
#
# <h3>For.e:</h3> <h4><em>df.loc[0:2, 'Hobbyist':'LanguageWorkedWith']</em></h4

# %% [markdown]
# <hr></hr>

# %% [markdown]
# # Loading CSV file (SURVEY)

# %%
import pandas as pd

# %%
df = pd.read_csv('../../DevSurvey2020/survey_results_public.csv')
schema_df = pd.read_csv('../../DevSurvey2020/survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows', 61)

# %%
df.head(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
# 5           6                     I am a developer by profession       No
# 6           7                     I am a developer by profession      Yes
# 7           8                     I am a developer by profession      Yes
# 8           9                     I am a developer by profession       No
# 9          10                     I am a developer by profession      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
# 5   NaN         14      NaN        NaN            NaN             Germany
# 6   NaN         18  Monthly        NaN            NaN               India
# 7  36.0         12   Yearly   116000.0       116000.0       United States
# 8  30.0         20      NaN        NaN            NaN             Tunisia
# 9  22.0         14   Yearly    25000.0        32315.0      United Kingdom
#
#            CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# 0         European Euro            EUR   Microsoft SQL Server
# 1        Pound sterling            GBP                    NaN
# 2                   NaN            NaN                    NaN
# 3          Albanian lek            ALL                    NaN
# 4                   NaN            NaN       MySQL;PostgreSQL
# 5         European Euro            EUR                    NaN
# 6  United States dollar            USD                    NaN
# 7  United States dollar            USD                MongoDB
# 8  United States dollar            USD                    NaN
# 9        Pound sterling            GBP   Microsoft SQL Server
#
#                           DatabaseWorkedWith  \
# 0  Elasticsearch;Microsoft SQL Server;Oracle
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4              MySQL;PostgreSQL;Redis;SQLite
# 5                                        NaN
# 6                                        NaN
# 7                        MariaDB;MySQL;Redis
# 8                                        NaN
# 9                       Microsoft SQL Server
#
#                                              DevType  \
# 0  Developer, desktop or enterprise applications;...
# 1            Developer, full-stack;Developer, mobile
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5    Designer;Developer, front-end;Developer, mobile
# 6  Developer, back-end;Developer, front-end;Devel...
# 7  Developer, back-end;Developer, desktop or ente...
# 8                              Developer, full-stack
# 9  Database administrator;Developer, full-stack;D...
#
#                                              EdLevel  \
# 0    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                NaN
# 3    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5  Secondary school (e.g. American high school, G...
# 6       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 7       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 8                 Professional degree (JD, MD, etc.)
# 9    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Employed full-time
# 2                                                NaN
# 3                                                NaN
# 4                                 Employed full-time
# 5                                 Employed full-time
# 6                                 Employed full-time
# 7                                 Employed full-time
# 8  Independent contractor, freelancer, or self-em...
# 9                                 Employed full-time
#
#                       Ethnicity Gender  \
# 0  White or of European descent    Man
# 1                           NaN    NaN
# 2                           NaN    NaN
# 3  White or of European descent    Man
# 4  White or of European descent    Man
# 5  White or of European descent    Man
# 6                           NaN    NaN
# 7  White or of European descent    Man
# 8                           NaN    Man
# 9  White or of European descent    Man
#
#                                           JobFactors                 JobSat  \
# 0  Languages, frameworks, and other technologies ...     Slightly satisfied
# 1                                                NaN      Very dissatisfied
# 2                                                NaN                    NaN
# 3  Flex time or a flexible schedule;Office enviro...  Slightly dissatisfied
# 4                                                NaN                    NaN
# 5  Diversity of the company or organization;Langu...     Slightly satisfied
# 6                                                NaN         Very satisfied
# 7  Remote work options;Opportunities for professi...  Slightly dissatisfied
# 8  Diversity of the company or organization;Remot...      Very dissatisfied
# 9  Flex time or a flexible schedule;How widely us...         Very satisfied
#
#                                              JobSeek  \
# 0       I am not interested in new job opportunities
# 1       I am not interested in new job opportunities
# 2                                                NaN
# 3  I’m not actively looking, but I am open to new...
# 4                                                NaN
# 5       I am not interested in new job opportunities
# 6  I’m not actively looking, but I am open to new...
# 7  I’m not actively looking, but I am open to new...
# 8  I’m not actively looking, but I am open to new...
# 9  I’m not actively looking, but I am open to new...
#
#                   LanguageDesireNextYear                   LanguageWorkedWith  \
# 0                 C#;HTML/CSS;JavaScript               C#;HTML/CSS;JavaScript
# 1                           Python;Swift                     JavaScript;Swift
# 2               Objective-C;Python;Swift             Objective-C;Python;Swift
# 3                                    NaN                                  NaN
# 4                        Java;Ruby;Scala                    HTML/CSS;Ruby;SQL
# 5               HTML/CSS;Java;JavaScript             HTML/CSS;Java;JavaScript
# 6                        C#;HTML/CSS;PHP                      C#;HTML/CSS;PHP
# 7                             JavaScript                           Python;SQL
# 8                            Python;Rust              HTML/CSS;JavaScript;PHP
# 9  HTML/CSS;Java;JavaScript;Python;R;SQL  HTML/CSS;Java;JavaScript;Python;SQL
#
#              MiscTechDesireNextYear MiscTechWorkedWith  \
# 0                 .NET Core;Xamarin     .NET;.NET Core
# 1  React Native;TensorFlow;Unity 3D       React Native
# 2                               NaN                NaN
# 3                               NaN                NaN
# 4                      Ansible;Chef            Ansible
# 5                               NaN                NaN
# 6                               NaN                NaN
# 7                          Unity 3D            Ansible
# 8                               NaN                NaN
# 9                 Pandas;TensorFlow             Pandas
#
#              NEWCollabToolsDesireNextYear  \
# 0  Microsoft Teams;Microsoft Azure;Trello
# 1                            Github;Slack
# 2                                     NaN
# 3                                     NaN
# 4   Github;Google Suite (Docs, Meet, etc)
# 5                            Github;Slack
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                  Github;Microsoft Teams
#
#                             NEWCollabToolsWorkedWith NEWDevOps  \
# 0       Confluence;Jira;Slack;Microsoft Azure;Trello        No
# 1                Confluence;Jira;Github;Gitlab;Slack       NaN
# 2                                                NaN       NaN
# 3                                                NaN        No
# 4  Confluence;Jira;Github;Slack;Google Suite (Doc...       NaN
# 5                     Confluence;Github;Slack;Trello  Not sure
# 6                                                NaN       Yes
# 7  Confluence;Jira;Github;Slack;Microsoft Teams;G...       Yes
# 8  Github;Slack;Trello;Google Suite (Docs, Meet, ...       NaN
# 9                             Github;Microsoft Teams        No
#
#          NEWDevOpsImpt                           NEWEdImpt  \
# 0   Somewhat important                    Fairly important
# 1                  NaN                    Fairly important
# 2                  NaN                                 NaN
# 3                  NaN  Not at all important/not necessary
# 4                  NaN                      Very important
# 5                  NaN                    Fairly important
# 6  Extremely important                      Very important
# 7  Extremely important  Not at all important/not necessary
# 8                  NaN                      Very important
# 9              Neutral                    Fairly important
#
#                                           NEWJobHunt  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Curious about other opportunities;Wanting to w...
# 4                                                NaN
# 5                                                NaN
# 6  Better compensation;Growth or leadership oppor...
# 7  Curious about other opportunities;Better compe...
# 8  Curious about other opportunities;Growth or le...
# 9  Curious about other opportunities;Better compe...
#
#                                   NEWJobHuntResearch          NEWLearn  \
# 0                                                NaN       Once a year
# 1                                                NaN       Once a year
# 2                                                NaN     Once a decade
# 3                                                NaN       Once a year
# 4                                                NaN       Once a year
# 5                                                NaN       Once a year
# 6  Read company media, such as employee blogs or ...  Every few months
# 7  Read company media, such as employee blogs or ...       Once a year
# 8                                                NaN       Once a year
# 9  Company reviews from third party sites (e.g. G...  Every few months
#
#   NEWOffTopic                NEWOnboardGood NEWOtherComms  \
# 0    Not sure                           NaN            No
# 1    Not sure                           NaN            No
# 2         NaN                           NaN            No
# 3    Not sure                           Yes           Yes
# 4          No                           NaN           Yes
# 5          No                            No            No
# 6         Yes                           Yes            No
# 7    Not sure                           Yes            No
# 8          No                           Yes            No
# 9         Yes  Onboarding? What onboarding?            No
#
#                                          NEWOvertime  \
# 0                   Often: 1-2 days per week or more
# 1                                                NaN
# 2                                                NaN
# 3  Occasionally: 1-2 days per quarter but less th...
# 4                                                NaN
# 5                                              Never
# 6  Sometimes: 1-2 days per month but less than we...
# 7  Occasionally: 1-2 days per quarter but less th...
# 8  Occasionally: 1-2 days per quarter but less th...
# 9                   Often: 1-2 days per week or more
#
#                                  NEWPurchaseResearch      NEWPurpleLink  \
# 0  Start a free trial;Ask developers I know/work ...             Amused
# 1                                                NaN             Amused
# 2                                                NaN                NaN
# 3                                                NaN                NaN
# 4  Start a free trial;Ask developers I know/work ...  Hello, old friend
# 5  Ask developers I know/work with;Read ratings o...             Amused
# 6  Start a free trial;Ask developers I know/work ...                NaN
# 7  Start a free trial;Ask developers I know/work ...  Hello, old friend
# 8                                 Start a free trial  Hello, old friend
# 9  Start a free trial;Ask developers I know/work ...  Hello, old friend
#
#                                           NEWSOSites  \
# 0   Stack Overflow (public Q&A for anyone who codes)
# 1  Stack Overflow (public Q&A for anyone who code...
# 2   Stack Overflow (public Q&A for anyone who codes)
# 3  Stack Overflow (public Q&A for anyone who code...
# 4  Stack Overflow (public Q&A for anyone who code...
# 5  Stack Overflow (public Q&A for anyone who code...
# 6   Stack Overflow (public Q&A for anyone who codes)
# 7  Stack Overflow (public Q&A for anyone who code...
# 8  Stack Overflow (public Q&A for anyone who code...
# 9  Stack Overflow (public Q&A for anyone who code...
#
#                                             NEWStuck        OpSys  \
# 0  Visit Stack Overflow;Go for a walk or other ph...      Windows
# 1  Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 2                                                NaN  Linux-based
# 3                                                NaN  Linux-based
# 4  Call a coworker or friend;Visit Stack Overflow...      Windows
# 5  Play games;Visit Stack Overflow;Watch help / t...      Windows
# 6                                                NaN      Windows
# 7  Play games;Call a coworker or friend;Visit Sta...  Linux-based
# 8                                           Meditate      Windows
# 9                               Visit Stack Overflow      Windows
#
#                                              OrgSize  \
# 0                                   2 to 9 employees
# 1                           1,000 to 4,999 employees
# 2                                                NaN
# 3                                 20 to 99 employees
# 4                                                NaN
# 5                                                NaN
# 6                                 20 to 99 employees
# 7                                 20 to 99 employees
# 8  Just me - I am a freelancer, sole proprietor, ...
# 9                                   2 to 9 employees
#
#                               PlatformDesireNextYear  \
# 0     Android;iOS;Kubernetes;Microsoft Azure;Windows
# 1                         iOS;Kubernetes;Linux;MacOS
# 2                                                NaN
# 3                                                NaN
# 4  Docker;Google Cloud Platform;Heroku;Linux;Windows
# 5                                            Android
# 6                                                NaN
# 7                    iOS;Slack Apps and Integrations
# 8                                                NaN
# 9                 Android;Linux;Raspberry Pi;Windows
#
#                    PlatformWorkedWith                      PurchaseWhat  \
# 0                             Windows                               NaN
# 1                                 iOS     I have little or no influence
# 2                                 NaN                               NaN
# 3                                 NaN  I have a great deal of influence
# 4      AWS;Docker;Linux;MacOS;Windows                               NaN
# 5            Android;Docker;WordPress             I have some influence
# 6                                 NaN                               NaN
# 7                              Docker             I have some influence
# 8                           WordPress                               NaN
# 9  Android;Linux;Raspberry Pi;Windows  I have a great deal of influence
#
#                  Sexuality SOAccount           SOComm  \
# 0  Straight / Heterosexual        No   No, not at all
# 1                      NaN       Yes  Yes, definitely
# 2                      NaN       Yes    Yes, somewhat
# 3  Straight / Heterosexual       Yes  Yes, definitely
# 4  Straight / Heterosexual       Yes    Yes, somewhat
# 5  Straight / Heterosexual       Yes    Yes, somewhat
# 6                      NaN       Yes  Yes, definitely
# 7  Straight / Heterosexual       Yes   No, not really
# 8  Straight / Heterosexual       Yes  Yes, definitely
# 9  Straight / Heterosexual       Yes  Yes, definitely
#
#                             SOPartFreq                      SOVisitFreq  \
# 0                                  NaN           Multiple times per day
# 1  Less than once per month or monthly           Multiple times per day
# 2      A few times per month or weekly            Daily or almost daily
# 3      A few times per month or weekly           Multiple times per day
# 4  Less than once per month or monthly  A few times per month or weekly
# 5      A few times per month or weekly             A few times per week
# 6               Multiple times per day           Multiple times per day
# 7  Less than once per month or monthly           Multiple times per day
# 8               Multiple times per day           Multiple times per day
# 9               Multiple times per day           Multiple times per day
#
#                    SurveyEase           SurveyLength Trans  \
# 0  Neither easy nor difficult  Appropriate in length    No
# 1                         NaN                    NaN   NaN
# 2  Neither easy nor difficult  Appropriate in length   NaN
# 3                         NaN                    NaN    No
# 4                        Easy              Too short    No
# 5  Neither easy nor difficult  Appropriate in length   NaN
# 6                         NaN                    NaN   NaN
# 7                        Easy  Appropriate in length    No
# 8  Neither easy nor difficult  Appropriate in length    No
# 9                        Easy  Appropriate in length    No
#
#                                       UndergradMajor  WebframeDesireNextYear  \
# 0  Computer science, computer engineering, or sof...            ASP.NET Core
# 1  Computer science, computer engineering, or sof...                     NaN
# 2                                                NaN                     NaN
# 3  Computer science, computer engineering, or sof...                     NaN
# 4  Computer science, computer engineering, or sof...    Django;Ruby on Rails
# 5                                                NaN                React.js
# 6  Computer science, computer engineering, or sof...                     NaN
# 7  Computer science, computer engineering, or sof...  Django;React.js;Vue.js
# 8  Computer science, computer engineering, or sof...              Angular.js
# 9                          Mathematics or statistics            Flask;jQuery
#
#      WebframeWorkedWith                             WelcomeChange  \
# 0  ASP.NET;ASP.NET Core   Just as welcome now as I felt last year
# 1                   NaN  Somewhat more welcome now than last year
# 2                   NaN  Somewhat more welcome now than last year
# 3                   NaN  Somewhat less welcome now than last year
# 4         Ruby on Rails   Just as welcome now as I felt last year
# 5                   NaN                                       NaN
# 6                   NaN     A lot more welcome now than last year
# 7                 Flask   Just as welcome now as I felt last year
# 8                jQuery   Just as welcome now as I felt last year
# 9          Flask;jQuery  Somewhat more welcome now than last year
#
#    WorkWeekHrs YearsCode YearsCodePro
# 0         50.0        36           27
# 1          NaN         7            4
# 2          NaN         4          NaN
# 3         40.0         7            4
# 4          NaN        15            8
# 5          NaN         6            4
# 6          NaN         6            4
# 7         39.0        17           13
# 8         50.0         6            4
# 9         36.0         8            4

# %%
df.shape
# Out:
# (64461, 61)

# %%
df.loc[0:2, 'Hobbyist':'Employment']
# Out:
#   Hobbyist  Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# 0      Yes  NaN         13  Monthly        NaN            NaN
# 1       No  NaN         19      NaN        NaN            NaN
# 2      Yes  NaN         15      NaN        NaN            NaN
#
#               Country    CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# 0             Germany   European Euro            EUR   Microsoft SQL Server
# 1      United Kingdom  Pound sterling            GBP                    NaN
# 2  Russian Federation             NaN            NaN                    NaN
#
#                           DatabaseWorkedWith  \
# 0  Elasticsearch;Microsoft SQL Server;Oracle
# 1                                        NaN
# 2                                        NaN
#
#                                              DevType  \
# 0  Developer, desktop or enterprise applications;...
# 1            Developer, full-stack;Developer, mobile
# 2                                                NaN
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                              NaN
#
#                                           Employment
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Employed full-time
# 2                                                NaN

# %%
# getting 'yes' and 'no' counts
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df.CurrencyDesc.unique()
# Out:
# array(['European Euro', 'Pound sterling', nan, 'Albanian lek',
#        'United States dollar', 'Indian rupee', 'Canadian dollar',
#        'Australian dollar', 'Brazilian real', 'Mexican peso',
#        'Swedish krona', 'Polish zloty', 'Indonesian rupiah',
#        'Israeli new shekel', 'Czech koruna',
#        'Bosnia and Herzegovina convertible mark', 'Bulgarian lev',
#        'Ukrainian hryvnia', 'Swiss franc', 'Hungarian forint',
#        'Nepalese rupee', 'Uruguayan peso', 'Pakistani rupee',
#        'Nigerian naira', 'Turkish lira', 'Philippine peso',
#        'Peruvian sol', 'Sri Lankan rupee', 'New Taiwan dollar',
#        'Kyrgyzstani som', 'Croatian kuna', 'Argentine peso',
#        'Russian ruble', 'Iranian rial', 'Ghanaian cedi',
#        'Norwegian krone', 'Moroccan dirham', 'Romanian leu',
#        'Tunisian dinar', 'Haitian gourde', 'Colombian peso',
#        'Honduran lempira', 'Danish krone', 'Lebanese pound',
#        'Ugandan shilling', 'Serbian dinar', 'Guatemalan quetzal',
#        'Syrian pound', 'Egyptian pound', 'Bangladeshi taka',
#        'United Arab Emirates dirham', 'South African rand',
#        'Belarusian ruble', 'Angolan kwanza', 'Chilean peso',
#        'Jordanian dinar', 'Georgian lari', 'Costa Rican colon',
#        'Saudi Arabian riyal', 'New Zealand dollar', 'Armenian dram',
#        'Moldovan leu', 'Cuban peso', 'Singapore dollar',
#        'Vietnamese dong', 'Azerbaijan manat', 'Dominican peso',
#        'Manx pound', 'Uzbekistani som', 'Trinidad and Tobago dollar',
#        'West African CFA franc', 'Icelandic krona', 'Kuwaiti dinar',
#        'Turkmen manat', 'Kenyan shilling', 'Hong Kong dollar',
#        'Tanzanian shilling', 'Bolivian boliviano', 'South Korean won',
#        'Japanese yen', 'Iraqi dinar', 'Paraguayan guarani',
#        'Malaysian ringgit', 'Thai baht', 'Chinese Yuan Renminbi',
#        'Myanmar kyat', 'Zambian kwacha', 'Kazakhstani tenge',
#        'Cambodian riel', 'Maldivian rufiyaa', 'Congolese franc',
#        'Macedonian denar', 'Malawian kwacha', 'Qatari riyal',
#        'Bermudian dollar', 'Algerian dinar', 'e\tCook Islands dollar',
#        'Netherlands Antillean guilder', 'Afghan afghani',
#        'Mongolian tugrik', 'Botswana pula', 'Djiboutian franc',
#        'Omani rial', 'Mauritanian ouguiya', 'Libyan dinar',
#        'Aruban florin', 'Ethiopian birr', 'Malagasy ariary',
#        'Namibian dollar', 'Rwandan franc', 'Swazi lilangeni',
#        'Bhutanese ngultrum', 'Central African CFA franc',
#        'Bahraini dinar', 'Yemeni rial', 'Barbadian dollar',
#        'Gibraltar pound', 'Venezuelan bolivar', 'Jamaican dollar',
#        'Nicaraguan cordoba', 'Sierra Leonean leone', 'Lao kip',
#        'Tajikistani somoni', 'Mauritian rupee', 'Somali shilling',
#        'Sudanese pound', 'Brunei dollar', 'SDR (Special Drawing Right)',
#        'Cayman Islands dollar', 'Guinean franc', 'Falkland Islands pound',
#        'CFP franc', 'Lesotho loti', 'Fijian dollar', 'Bahamian dollar',
#        'East Caribbean dollar', 'Gambian dalasi', 'Guyanese dollar',
#        'Samoan tala', 'e\tFaroese krona', 'Belize dollar',
#        'Mozambican metical', 'Macanese pataca'], dtype=object)

# %%
df.CurrencyDesc.nunique()
# ^ the # of unique values
# Out:
# 142

# %% [markdown]
# # Cross tabulation

# %%
pd.crosstab(df.CurrencyDesc, df.Country)
# ^ a tally account of how many people belong to each combination of currency and country
# Out:
# Country                 Afghanistan  Albania  Algeria  Andorra  Angola  \
# CurrencyDesc
# Afghan afghani                   24        1        0        0       0
# Albanian lek                      2       22        0        0       0
# Algerian dinar                    0        0       25        0       0
# Angolan kwanza                    0        1        0        0       2
# Argentine peso                    0        0        0        1       0
# ...                             ...      ...      ...      ...     ...
# West African CFA franc            0        0        0        0       0
# Yemeni rial                       0        0        0        0       0
# Zambian kwacha                    0        0        0        0       0
# e\tCook Islands dollar            0        0        0        0       1
# e\tFaroese krona                  0        0        0        0       0
#
# Country                 Antigua and Barbuda  Argentina  Armenia  Australia  \
# CurrencyDesc
# Afghan afghani                            0          0        0          0
# Albanian lek                              0          0        0          0
# Algerian dinar                            0          0        0          0
# Angolan kwanza                            0          0        0          0
# Argentine peso                            1        253        0          0
# ...                                     ...        ...      ...        ...
# West African CFA franc                    0          0        0          0
# Yemeni rial                               0          0        0          0
# Zambian kwacha                            0          0        0          0
# e\tCook Islands dollar                    0          0        0          0
# e\tFaroese krona                          0          0        0          0
#
# Country                 Austria  Azerbaijan  Bahamas  Bahrain  Bangladesh  \
# CurrencyDesc
# Afghan afghani                0           0        0        0           0
# Albanian lek                  0           0        0        0           1
# Algerian dinar                0           0        0        0           1
# Angolan kwanza                0           0        0        0           0
# Argentine peso                0           0        0        0           0
# ...                         ...         ...      ...      ...         ...
# West African CFA franc        0           0        0        0           0
# Yemeni rial                   0           0        0        0           0
# Zambian kwacha                0           0        0        0           0
# e\tCook Islands dollar        0           0        0        0           0
# e\tFaroese krona              0           0        0        0           0
#
# Country                 Barbados  Belarus  Belgium  Belize  Benin  Bhutan  \
# CurrencyDesc
# Afghan afghani                 0        0        0       0      0       0
# Albanian lek                   0        0        0       0      0       0
# Algerian dinar                 0        0        0       0      0       0
# Angolan kwanza                 0        0        0       0      0       0
# Argentine peso                 0        0        0       0      0       0
# ...                          ...      ...      ...     ...    ...     ...
# West African CFA franc         0        0        0       0      3       0
# Yemeni rial                    0        0        0       0      0       0
# Zambian kwacha                 0        1        0       0      0       0
# e\tCook Islands dollar         0        0        0       0      0       0
# e\tFaroese krona               0        0        0       0      0       0
#
# Country                 Bolivia  Bosnia and Herzegovina  Botswana  Brazil  \
# CurrencyDesc
# Afghan afghani                0                       0         0       0
# Albanian lek                  0                       0         0       0
# Algerian dinar                0                       0         0       0
# Angolan kwanza                0                       0         0       1
# Argentine peso                0                       0         0       0
# ...                         ...                     ...       ...     ...
# West African CFA franc        0                       0         0       0
# Yemeni rial                   0                       0         0       0
# Zambian kwacha                0                       0         0       0
# e\tCook Islands dollar        0                       0         0       0
# e\tFaroese krona              0                       0         0       0
#
# Country                 Brunei Darussalam  Bulgaria  Burkina Faso  Cambodia  \
# CurrencyDesc
# Afghan afghani                          0         0             0         0
# Albanian lek                            0         0             0         0
# Algerian dinar                          0         0             0         0
# Angolan kwanza                          0         0             0         0
# Argentine peso                          0         0             0         0
# ...                                   ...       ...           ...       ...
# West African CFA franc                  0         0             0         0
# Yemeni rial                             0         0             0         0
# Zambian kwacha                          0         0             0         0
# e\tCook Islands dollar                  0         0             0         0
# e\tFaroese krona                        0         0             0         0
#
# Country                 Cameroon  Canada  ...  South Korea  Spain  Sri Lanka  \
# CurrencyDesc                              ...
# Afghan afghani                 0       0  ...            0      0          0
# Albanian lek                   0       0  ...            1      0          0
# Algerian dinar                 0       0  ...            0      0          0
# Angolan kwanza                 0       0  ...            0      0          0
# Argentine peso                 0       0  ...            0      0          0
# ...                          ...     ...  ...          ...    ...        ...
# West African CFA franc         1       0  ...            0      0          0
# Yemeni rial                    0       0  ...            0      0          0
# Zambian kwacha                 0       0  ...            0      0          0
# e\tCook Islands dollar         0       0  ...            0      0          0
# e\tFaroese krona               0       0  ...            0      0          0
#
# Country                 Sudan  Swaziland  Sweden  Switzerland  \
# CurrencyDesc
# Afghan afghani              0          0       0            0
# Albanian lek                0          0       0            0
# Algerian dinar              0          0       0            0
# Angolan kwanza              0          0       0            0
# Argentine peso              0          0       1            0
# ...                       ...        ...     ...          ...
# West African CFA franc      0          0       0            0
# Yemeni rial                 0          0       0            0
# Zambian kwacha              0          0       0            0
# e\tCook Islands dollar      0          0       0            0
# e\tFaroese krona            0          0       0            0
#
# Country                 Syrian Arab Republic  Taiwan  Tajikistan  Thailand  \
# CurrencyDesc
# Afghan afghani                             0       0           0         0
# Albanian lek                               0       0           0         1
# Algerian dinar                             0       0           0         0
# Angolan kwanza                             0       0           0         0
# Argentine peso                             0       0           0         0
# ...                                      ...     ...         ...       ...
# West African CFA franc                     0       0           0         0
# Yemeni rial                                0       0           0         1
# Zambian kwacha                             0       0           0         0
# e\tCook Islands dollar                     0       0           0         0
# e\tFaroese krona                           0       0           0         0
#
# Country                 The former Yugoslav Republic of Macedonia  Togo  \
# CurrencyDesc
# Afghan afghani                                                  0     0
# Albanian lek                                                    0     0
# Algerian dinar                                                  0     0
# Angolan kwanza                                                  0     0
# Argentine peso                                                  0     0
# ...                                                           ...   ...
# West African CFA franc                                          0     5
# Yemeni rial                                                     0     0
# Zambian kwacha                                                  0     0
# e\tCook Islands dollar                                          0     0
# e\tFaroese krona                                                0     0
#
# Country                 Trinidad and Tobago  Tunisia  Turkey  Turkmenistan  \
# CurrencyDesc
# Afghan afghani                            0        0       0             0
# Albanian lek                              0        0       0             0
# Algerian dinar                            0        0       0             0
# Angolan kwanza                            0        0       0             0
# Argentine peso                            0        0       0             0
# ...                                     ...      ...     ...           ...
# West African CFA franc                    0        0       0             0
# Yemeni rial                               0        0       0             0
# Zambian kwacha                            0        0       0             0
# e\tCook Islands dollar                    0        0       0             0
# e\tFaroese krona                          0        0       0             0
#
# Country                 Uganda  Ukraine  United Arab Emirates  United Kingdom  \
# CurrencyDesc
# Afghan afghani               0        0                     0               0
# Albanian lek                 0        0                     0               0
# Algerian dinar               0        0                     0               0
# Angolan kwanza               0        0                     0               1
# Argentine peso               0        0                     0               0
# ...                        ...      ...                   ...             ...
# West African CFA franc       0        0                     0               0
# Yemeni rial                  0        0                     0               0
# Zambian kwacha               0        1                     0               1
# e\tCook Islands dollar       0        0                     0               0
# e\tFaroese krona             0        0                     0               0
#
# Country                 United Republic of Tanzania  United States  Uruguay  \
# CurrencyDesc
# Afghan afghani                                    0              0        0
# Albanian lek                                      0              0        0
# Algerian dinar                                    0              0        0
# Angolan kwanza                                    0              1        0
# Argentine peso                                    0              1        0
# ...                                             ...            ...      ...
# West African CFA franc                            0              0        0
# Yemeni rial                                       0              0        0
# Zambian kwacha                                    0              1        0
# e\tCook Islands dollar                            0              0        0
# e\tFaroese krona                                  0              0        0
#
# Country                 Uzbekistan  Venezuela, Bolivarian Republic of...  \
# CurrencyDesc
# Afghan afghani                   0                                     0
# Albanian lek                     0                                     0
# Algerian dinar                   0                                     0
# Angolan kwanza                   0                                     0
# Argentine peso                   0                                     0
# ...                            ...                                   ...
# West African CFA franc           0                                     0
# Yemeni rial                      0                                     0
# Zambian kwacha                   0                                     0
# e\tCook Islands dollar           0                                     0
# e\tFaroese krona                 0                                     0
#
# Country                 Viet Nam  Yemen  Zambia  Zimbabwe
# CurrencyDesc
# Afghan afghani                 0      0       0         0
# Albanian lek                   0      0       0         0
# Algerian dinar                 0      0       0         0
# Angolan kwanza                 0      0       0         0
# Argentine peso                 0      0       0         0
# ...                          ...    ...     ...       ...
# West African CFA franc         0      0       0         0
# Yemeni rial                    0      0       0         0
# Zambian kwacha                 0      0       8         0
# e\tCook Islands dollar         0      0       0         0
# e\tFaroese krona               0      0       0         0
#
# [142 rows x 172 columns]

# %%
# %matplotlib inline

# %%
df.CurrencyDesc.head(50).value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.Age.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>
